# %%
from mp_api.client import MPRester
import matplotlib.pyplot as plt

# %%
with MPRester(api_key="WhXDRGC9F1eObKDDH0PZ3FJcqQ9kDSp0") as mpr:
    list = mpr.materials.xas.search(absorbing_element='Ti', elements=["O","Ti"],spectrum_type='XANES')

print(list)
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/mp_api/client/mprester.py:193: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# Retrieving XASDoc documents:  58%|█████▊    | 1395/2395 [00:18<00:01, 703.75it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-8f6652069ca3> in <module>
#       1 with MPRester(api_key="WhXDRGC9F1eObKDDH0PZ3FJcqQ9kDSp0") as mpr:
# ----> 2     list = mpr.materials.xas.search(absorbing_element='Ti', elements=["O","Ti"],spectrum_type='XANES')
#       3
#       4 print(list)
#
# ...

# %%
print(list)
# Out:
# <class 'list'>

# %%
with MPRester(api_key="WhXDRGC9F1eObKDDH0PZ3FJcqQ9kDSp0") as mpr:
    tio2 = mpr.materials.xas.search(material_ids=["mp-1439"],absorbing_element='Ti',edge='L3')
    tio = mpr.materials.xas.search(material_ids=['mp-2664'],absorbing_element='Ti',edge='L3')
# Out:
# ...
# Retrieving XASDoc documents: 100%|██████████| 1/1 [00:00<00:00, 18477.11it/s]

# %%
print(tio[0])
# Out:
# MPDataDoc<XASDoc>
# nsites=2,
# elements=[Element O, Element Ti],
# nelements=2,
# composition=Composition('O1 Ti1'),
# composition_reduced=Composition('O1 Ti1'),
# formula_pretty='TiO',
# formula_anonymous='AB',
# chemsys='O-Ti',
# volume=19.729690607297158,
# density=5.375281987697856,
# symmetry=SymmetryData(crystal_system=<CrystalSystem.cubic: 'Cubic'>, symbol='Fm-3m', number=225, point_group='m-3m', symprec=0.1, version=None),
# material_id=MPID(mp-2664),
# spectrum_id='mp-2664-XANES-Ti-L3',
# last_updated=datetime.datetime(2019, 6, 1, 14, 20, 54, 254000),
# spectrum=Ti L3 Edge XANES for TiO: <super: <class 'XAS'>, <XAS object>>,
# absorbing_element=Element Ti,
# spectrum_type=<Type.XANES: 'XANES'>,
# edge=<Edge.L3: 'L3'>
#
# Fields not requested:
# ['builder_meta', 'density_atomic', 'spectrum_name', 'warnings', 'task_ids']

# %%
plt.plot(tio2[0].spectrum.x,tio2[0].spectrum.y)
plt.plot(tio[0].spectrum.x,tio[0].spectrum.y)
plt.xlim((450,470))
# Out:
# (450.0, 470.0)
